# %%
import mne
import os
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import mne
#       2 import os
#
# File c:\University Work\final-year-project-code\.venv\Lib\site-packages\mne\__init__.py:35
#      32 # initialize logging
#      33 from .utils import set_log_level, set_log_file
# ---> 35 set_log_level(None, False)
#      36 set_log_file()
#
# File c:\University Work\final-year-project-code\.venv\Lib\site-packages\mne\utils\_logging.py:210, in set_log_level(verbose, return_old_level, add_frames)
#     189 """Set the logging level.
#     190
#     191 Parameters
#    (...)    207     The old level. Only returned if ``return_old_level`` is True.
#     208 """
#     209 old_verbose = logger.level
# --> 210 verbose = _parse_verbose(verbose)
#     212 if verbose != old_verbose:
#     213     logger.setLevel(verbose)
#
# ...

# %% [markdown]
# ## Constants
#
# This basically has constants and stuff used in this file

# %%
DATA_PATH = r"../eeg-data/reannotated"
PATIENT = "S001"

def get_data_path(patient=PATIENT, data_path=DATA_PATH, trial=1):
    parent = f"{data_path}/{patient}"
# Out:
# ['$Recycle.Bin', '.cache', '.Trash-1000', '.Xilinx', 'Documents and Settings', 'DumpStack.log', 'DumpStack.log.tmp', 'hiberfil.sys', 'inetpub', 'OneDriveTemp', 'pagefile.sys', 'PerfLogs', 'Program Files', 'Program Files (x86)', 'ProgramData', 'Recovery', 'swapfile.sys', 'System Volume Information', 'test', 'University Work', 'Users', 'Windows', 'Windows Obsidian Vaults', 'Windows.old', 'Wuthering Waves Game', 'Xilinx']

# %%
# Reading files

path = get_data_path()
mne.io.read_raw_fif(path)
